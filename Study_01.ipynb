# %%
from google.colab import drive
drive.mount('/content/drive')

cd /content/drive/MyDrive/BigData_Study/BigData_Exam
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-564c82d36024> in <module>()
#       2 drive.mount('/content/drive')
#       3
# ----> 4 cd /content/drive/MyDrive/BigData_Study/BigData_Exam
#       5
#       6 get_ipython().system("git config --global user.email 'dydwns9436@naver.com'")
#
# NameError: name 'cd' is not defined

# %%
# !git config --global user.email 'dydwns9436@naver.com'
# !git config --global user.name 'dydwns9436'

# !git add Study_01.ipynb

# !git commit -m '2022-05-27'
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
a = 1
print(a)
# Out:
# 1

# %%
b=5
a=b
print(a)
# Out:
# 5

# %%
a=10
b=5
c=3
print(a+b, a-b, a*b, a/b)
print(a**c, a//c, a%c)
# Out:
# 15 5 50 2.0
# 1000 3 1

# %%
str1="python"
str2="programming"
print(str1+str2)
print(str1*2)
# Out:
# pythonprogramming
# pythonpython

# %%
str=str1+" "+str2
print(str[0], str[1], str[10])

print(str[0:4])

print(str[5:9])
# Out:
# p y g
# pyth
# n pr

# %%
print("오늘은 %d일 입니다." %13)
print("오늘은 %s일 입니다." %"수요일")
print("오늘은 %f도 입니다." %32.7) #실수형 기본값은 소수점 아래 6자리까지 출력
print("오늘은 %0.2f도 입니다." %32.7)
# Out:
# 오늘은 13일 입니다.
# 오늘은 수요일일 입니다.
# 오늘은 32.700000도 입니다.
# 오늘은 32.70도 입니다.

# %%
#%s : 문자열, %c : 단일문자, %d : 정수, %f : 실수, %o : 8진수, %x : 16진수

# %%
str.count('p') #str문자열에서 p라는 문자의 개수
# Out:
# 2

# %%
'/'.join(str) #문자열 삽입
# Out:
# 'p/y/t/h/o/n/ /p/r/o/g/r/a/m/m/i/n/g'

# %%
str.find('m') #m이 처음 나온 위치 반환
# Out:
# 13

# %%
str.replace('python','c')
# Out:
# 'c programming'

# %%
str.split(' ')
# Out:
# ['python', 'programming']

# %%
a=10
if(a>0):
    print('a는 양의 정수입니다.')
# Out:
# a는 양의 정수입니다.

# %%
if(a<0):
    print('a는 양의 정수입니다.')
print(a)
# Out:
# 10

# %%
a=-10

if(a>0):
    print('a는 %d이며 양의 정수입니다.' %a)

else:
    print('a는 %d이며 음의 정수입니다.' %a)
# Out:
# a는 -10이며 음의 정수입니다.

# %%
a=-10

if(a>0):
    print('a는 양의 정수입니다.')

elif(a==0):
    print('a는 0입니다.')

else:
    print('a는 음의 정수입니다.')
# Out:
# a는 음의 정수입니다.

# %% [markdown]
# #입력함수

# %%
a=int(input("첫 번째 수를 입력하세요 > "))
b=int(input("두 번째 수를 입력하세요 > "))
c=int(input("세 번째 수를 입력하세요 > "))

if(a>=b):
    big=a
else:
    big=b
    
if(c>=big):
    print('가장 큰 수는 %d입니다.'%c)
else:
    print('가장 큰 수는 %d입니다.'%big)
# Out:
# 첫 번째 수를 입력하세요 > 10
# 두 번째 수를 입력하세요 > 5
# 세 번째 수를 입력하세요 > 1
# 가장 큰 수는 10입니다.

# %% [markdown]
# #반복문-for문

# %%
for i in range(5):
    print(str)
# Out:
# python programming
# python programming
# python programming
# python programming
# python programming

# %%
sum=0

for i in range(1,6):
    sum+=i
    print('i의 값 : %d, 합계 : %d' %(i, sum))
# Out:
# i의 값 : 1, 합계 : 1
# i의 값 : 2, 합계 : 3
# i의 값 : 3, 합계 : 6
# i의 값 : 4, 합계 : 10
# i의 값 : 5, 합계 : 15

# %%
for i in range(0, 10, 2):
    print(i, end=' ')
# Out:
# 0 2 4 6 8

# %%
for x in 'python':
    print(x)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range(2,10):
    print('%d단' %i, end=' ')
    for j in range(1,10):
        print(i*j, end=' ')
    print()
# Out:
# 2단 2 4 6 8 10 12 14 16 18
# 3단 3 6 9 12 15 18 21 24 27
# 4단 4 8 12 16 20 24 28 32 36
# 5단 5 10 15 20 25 30 35 40 45
# 6단 6 12 18 24 30 36 42 48 54
# 7단 7 14 21 28 35 42 49 56 63
# 8단 8 16 24 32 40 48 56 64 72
# 9단 9 18 27 36 45 54 63 72 81

# %% [markdown]
# #반복문-while문

# %%
i=1
while i <=5:
    print(i,str)
    i+=1
# Out:
# 1 python programming
# 2 python programming
# 3 python programming
# 4 python programming
# 5 python programming

# %%
sum=0
i=1
while i <=5:
    sum+=i
    print('i의 값 : %d, 합계 : %d' %(i, sum))
    i+=1
# Out:
# i의 값 : 1, 합계 : 1
# i의 값 : 2, 합계 : 3
# i의 값 : 3, 합계 : 6
# i의 값 : 4, 합계 : 10
# i의 값 : 5, 합계 : 15

# %%
i=0
s=str

while i <= (len(s)-1): #i가 17과 같거나 작을 동안
    print(s[i], end=' ')
    i+=1
# Out:
# p y t h o n   p r o g r a m m i n g

# %%
len(s)
# Out:
# 18

# %%
avg_data=[70,60,55,95,80,70,85,47,83,78]

# %%
#for문

sum=0
avg=0

for x in avg_data:
    sum+=x

avg=sum/len(avg_data)
print('평균은 %0.2f입니다.' %avg)
# Out:
# 평균은 72.30입니다.

# %%
#while문

sum=0
avg=0

i=0
while i < len(a):
    sum+=a[i]
    i+=1

avg= sum/len(avg_data)
print('평균은 %0.2f입니다.' %avg)
# Out:
# 평균은 72.30입니다.

# %%
# Out:
# 10
