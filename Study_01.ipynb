# %% [markdown]
# #깃허브 연동

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/BigData_Study/BigData_Exam
# Out:
# /content/drive/MyDrive/BigData_Study/BigData_Exam

# %%
# !git config --global user.email 'dydwns9436@naver.com'
# !git config --global user.name 'dydwns9436'

# !git add Study_01.ipynb

# !git commit -m '2022-05-27'
# !git push
# Out:
# [main cf653d7] 2022-05-27
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Study_01.ipynb (93%)
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 489 bytes | 163.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dydwns9436/BigData_Exam.git
#    75f4607..cf653d7  main -> main

# %% [markdown]
# #기초

# %%
a = 1
print(a)
# Out:
# 1

# %%
b=5
a=b
print(a)
# Out:
# 5

# %% [markdown]
# #연산

# %%
a=10
b=5
c=3
print(a+b, a-b, a*b, a/b)
print(a**c, a//c, a%c)
# Out:
# 15 5 50 2.0
# 1000 3 1

# %%
str1="python"
str2="programming"
print(str1+str2)
print(str1*2)
# Out:
# pythonprogramming
# pythonpython

# %%
str=str1+" "+str2
print(str[0], str[1], str[10])

print(str[0:4])

print(str[5:9])
# Out:
# p y g
# pyth
# n pr

# %% [markdown]
# #포맷팅

# %%
print("오늘은 %d일 입니다." %13)
print("오늘은 %s일 입니다." %"수요일")
print("오늘은 %f도 입니다." %32.7) #실수형 기본값은 소수점 아래 6자리까지 출력
print("오늘은 %0.2f도 입니다." %32.7)
# Out:
# 오늘은 13일 입니다.
# 오늘은 수요일일 입니다.
# 오늘은 32.700000도 입니다.
# 오늘은 32.70도 입니다.

# %%
#%s : 문자열, %c : 단일문자, %d : 정수, %f : 실수, %o : 8진수, %x : 16진수

# %% [markdown]
# #문자열 함수

# %%
str.count('p') #str문자열에서 p라는 문자의 개수
# Out:
# 2

# %%
'/'.join(str) #문자열 삽입
# Out:
# 'p/y/t/h/o/n/ /p/r/o/g/r/a/m/m/i/n/g'

# %%
str.find('m') #m이 처음 나온 위치 반환
# Out:
# 13

# %%
str.replace('python','c')
# Out:
# 'c programming'

# %%
str.split(' ')
# Out:
# ['python', 'programming']

# %% [markdown]
# #조건문 - if문

# %%
a=10
if(a>0):
    print('a는 양의 정수입니다.')
# Out:
# a는 양의 정수입니다.

# %%
if(a<0):
    print('a는 양의 정수입니다.')
print(a)
# Out:
# 10

# %%
a=-10

if(a>0):
    print('a는 %d이며 양의 정수입니다.' %a)

else:
    print('a는 %d이며 음의 정수입니다.' %a)
# Out:
# a는 -10이며 음의 정수입니다.

# %%
a=-10

if(a>0):
    print('a는 양의 정수입니다.')

elif(a==0):
    print('a는 0입니다.')

else:
    print('a는 음의 정수입니다.')
# Out:
# a는 음의 정수입니다.

# %% [markdown]
# #입력함수

# %%
a=int(input("첫 번째 수를 입력하세요 > "))
b=int(input("두 번째 수를 입력하세요 > "))
c=int(input("세 번째 수를 입력하세요 > "))

if(a>=b):
    big=a
else:
    big=b
    
if(c>=big):
    print('가장 큰 수는 %d입니다.'%c)
else:
    print('가장 큰 수는 %d입니다.'%big)
# Out:
# 첫 번째 수를 입력하세요 > 10
# 두 번째 수를 입력하세요 > 5
# 세 번째 수를 입력하세요 > 1
# 가장 큰 수는 10입니다.

# %% [markdown]
# #반복문 - for문

# %%
for i in range(5):
    print(str)
# Out:
# python programming
# python programming
# python programming
# python programming
# python programming

# %%
sum=0

for i in range(1,6):
    sum+=i
    print('i의 값 : %d, 합계 : %d' %(i, sum))
# Out:
# i의 값 : 1, 합계 : 1
# i의 값 : 2, 합계 : 3
# i의 값 : 3, 합계 : 6
# i의 값 : 4, 합계 : 10
# i의 값 : 5, 합계 : 15

# %%
for i in range(0, 10, 2):
    print(i, end=' ')
# Out:
# 0 2 4 6 8

# %%
for x in 'python':
    print(x)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range(2,10):
    print('%d단' %i, end=' ')
    for j in range(1,10):
        print(i*j, end=' ')
    print()
# Out:
# 2단 2 4 6 8 10 12 14 16 18
# 3단 3 6 9 12 15 18 21 24 27
# 4단 4 8 12 16 20 24 28 32 36
# 5단 5 10 15 20 25 30 35 40 45
# 6단 6 12 18 24 30 36 42 48 54
# 7단 7 14 21 28 35 42 49 56 63
# 8단 8 16 24 32 40 48 56 64 72
# 9단 9 18 27 36 45 54 63 72 81

# %% [markdown]
# #반복문 - while문

# %%
i=1
while i <=5:
    print(i,str)
    i+=1
# Out:
# 1 python programming
# 2 python programming
# 3 python programming
# 4 python programming
# 5 python programming

# %%
sum=0
i=1
while i <=5:
    sum+=i
    print('i의 값 : %d, 합계 : %d' %(i, sum))
    i+=1
# Out:
# i의 값 : 1, 합계 : 1
# i의 값 : 2, 합계 : 3
# i의 값 : 3, 합계 : 6
# i의 값 : 4, 합계 : 10
# i의 값 : 5, 합계 : 15

# %%
i=0
s=str

while i <= (len(s)-1): #i가 17과 같거나 작을 동안
    print(s[i], end=' ')
    i+=1
# Out:
# p y t h o n   p r o g r a m m i n g

# %%
len(s)
# Out:
# 18

# %% [markdown]
# #평균 구하기

# %%
avg_data=[70,60,55,95,80,70,85,47,83,78]

# %%
#for문

sum=0
avg=0

for x in avg_data:
    sum+=x

avg=sum/len(avg_data)
print('평균은 %0.2f입니다.' %avg)
# Out:
# 평균은 72.30입니다.

# %%
#while문

sum=0
avg=0

i=0
while i < len(a):
    sum+=a[i]
    i+=1

avg= sum/len(avg_data)
print('평균은 %0.2f입니다.' %avg)
# Out:
# 평균은 72.30입니다.

# %% [markdown]
# # 리스트, 튜플, 딕셔너리

# %% [markdown]
# ##1. 리스트
# JAVA, C의 배열과 유사한 개념으로 자료의 집합을 표현
#
# for이나 while과 같은 반복문에서 사용 시 더욱 효율적
#
# [ ]로 감싸고 각 원소들은 쉼표로 구분

# %%
a=[]
b=[1,2,3]
c=['사과', '오렌지', '딸기', '포도', '바나나']
d=[1, 2, 'python', 'programming']

# %%
a=[1,2,3,4,5]
print(a)
print(a[0], a[-1], a[0]+a[1], a[0]*2)
# Out:
# [1, 2, 3, 4, 5]
# 1 5 3 2

# %%
a=[1,2,3]
b=[4,5,6]

print(a+b) #두 리스트를 연결
print(a*3) #주어진 횟수만큼 리스트 반복
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a=['a', 'b', 'c']

a.append('d') #맨 뒤에 d 원소 추가
print(a)

a.insert(1, 'aa') #a[1]자리에 aa 원소 추가
print(a)
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'aa', 'b', 'c', 'd']

# %%
a=['a', 'b', 'c']

a[2] = 'f'
print(a)
# Out:
# ['a', 'b', 'f']

# %%
a=['a', 'b', 'c']

del a[1]
print(a)
# Out:
# ['a', 'c']

# %%
a=['a','b','c','c','d','e']

print(a.count('c'))
a.remove('c') #첫번째로 나오는 c를 제거
print(a)
# Out:
# 2
# ['a', 'b', 'c', 'd', 'e']

# %%
scores=[[70, 75], [80,90], [100,90], [95,85], [82,92]]

print(scores[0][0])
print(scores[0][1])
# Out:
# 70
# 75

# %% [markdown]
# ## 2. 튜플과 딕셔너리
# 리스트와 유사하지만 값 변경이 불가능한 구조
#
# 프로그램이 실행되는 동안 값을 유지해야한다면 튜플, 수시로 값을 변경해야한다면 리스트 사용
#
# 딕셔너리는 대응관계를 표현하는 자료형으로 키와 값을 한 쌍으로 갖음

# %% [markdown]
# ### 2-1. 튜플

# %%
t=('a','b','c','d','e')
print(t[0])
print(t[2:])
print(t*2)
print(len(t))
# Out:
# a
# ('c', 'd', 'e')
# ('a', 'b', 'c', 'd', 'e', 'a', 'b', 'c', 'd', 'e')
# 5

# %% [markdown]
# ###2-2. 딕셔너리

# %%
dic1={1:'a', 2:'b',3:'c'}
dic2={'name':'YJ', 'age':27, 'e-mail':'dydwns9436@naver.com'}

print(dic1[1])
print(dic2['name'])
print(dic2['e-mail'])
# Out:
# a
# YJ
# dydwns9436@naver.com

# %%
dic1={1:'a', 2:'b',3:'c'}
dic2={'name':'YJ', 'age':27, 'e-mail':'dydwns9436@naver.com'}

dic1[5]='f'
print(dic1)

dic2['sex']='male'
print(dic2)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 5: 'f'}
# {'name': 'YJ', 'age': 27, 'e-mail': 'dydwns9436@naver.com', 'sex': 'male'}

# %%
dic1={1:'a', 2:'b',3:'c'}
dic2={'name':'YJ', 'age':27, 'e-mail':'dydwns9436@naver.com'}

print(dic1.keys())
print(dic2.values())
print(dic1.items()) #dic1의 키 값쌍을 dict_items 객체로 반환

if 'age' in dic2:
    print(dic2.get('age')) #해당 키에 값을 가져옴
# Out:
# dict_keys([1, 2, 3])
# dict_values(['YJ', 27, 'dydwns9436@naver.com'])
# dict_items([(1, 'a'), (2, 'b'), (3, 'c')])
# 27

# %%
id_pass = {'cuk':'12ab', 'python':'11aa', 'bigdata':'cc21','dydwns9436':'11vc'}

id=input('ID ')
password = input('PW ')

if id in id_pass: #입력한 키가 딕셔너리 키에 존재할 때
    if password == id_pass.get(id): #키와 값이 일치할 때
        print('로그인 되었습니다.')
    else : #키는 맞았으나 값이 틀릴 때
        print('비밀번호를 확인하세요.')

else: #입력한 키가 딕셔너리 키에 존재하지 않을 때
    print('아이디가 존재하지 않습니다.')
# Out:
# ID dydwns9436
# PW yongjun7114
# 로그인 되었습니다.

# %% [markdown]
# # 함수와 라이브러리

# %% [markdown]
# ## 1. 함수

# %%
def sum(a, b):
    return a+b

sum(2,3)
# Out:
# 5

# %% [markdown]
# *파이썬 내장함수 종류*
#
# abs() : 숫자의 절대값 반환
#
# round() : 소수점 이하 반올림 값 반환
#
# float() : 문자열이나 정수형 숫자를 실수로 변환
#
# str() : 객체를 문자열로 변환
#
# type() : 데이터의 자료형을 반환

# %%
type(a)
# Out:
# list

# %% [markdown]
# ## 2. 모듈&패키지
#
# 모듈 : 함수나 클래스를 모아놓은 파일
#
# 패키지 : 모듈을 묶어서 하나로 제공하는 개념
#
# import : 모듈과 패키지를 불러오는 명령어
#
# !pip list : 설치된 패키지 확인

# %% [markdown]
# ### 2-2. 자주 사용되는 파이썬 라이브러리(패키지)
#
# 배열/선형대수 : numpy
#
# 통계 : scipy
#
# 데이터 다루기 : pandas
#
# 머신러닝 : scikit learn
#
# 딥러닝 : tenserflow, keras, pytorch
#
# 시각화 : matplotlib, seaborn
