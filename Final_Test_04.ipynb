# %% [markdown]
# #필요한 패키지 import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #데이터 불러오기

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/stroke_/train.csv')

# %%
df

# %%
df.info()

# %%
Q1 = df['bmi'].describe()['25%']
Q2 = df['bmi'].describe()['50%']
Q3 = df['bmi'].describe()['75%']

IQR = Q3 - Q1
print(Q2, IQR)

# %% [markdown]
# Q1.  성별이 Male인 환자들의 age의 평균값은 ?

# %%
df.columns

# %%
df['age'] = df['age'].str.replace('*', '').astype('int')

# %%
df['age'].unique()

# %%
q1 = df[df.gender == 'Male']['age'].mean()
print(q1)

# %% [markdown]
# Q2. bmi컬럼의 결측치를 bmi컬럼의 결측치를 제외한 나머지 값들의 중앙값으로 채웠을 경우 bmi 컬럼의 평균을 소숫점 이하 3자리 까지 구하여라

# %%
df['bmi_median'] = df['bmi'].fillna(df['bmi'].median())

q2 = df['bmi_median'].mean()

print(round(q2, 3))

# %% [markdown]
# Q3. bmi컬럼의 각 결측치들을 직전의 행의 bmi값으로 채웠을 경우 bmi 컬럼의 평균을 소숫점 이하 3자리 까지 구하여라

# %%
df['bmi_front'] = df['bmi'].fillna(method = 'ffill') #후행 대체는 bfill

print(round(df.bmi_front.mean(), 3))

# %% [markdown]
# Q4.  bmi컬럼의 각 결측치들을 결측치를 가진 환자 나이대(10단위)의 평균 bmi 값으로 대체한 후 대체된 bmi 컬럼의 평균을 소숫점 이하 3자리 까지 구하여라

# %%
df.groupby(df['age']//10)['bmi'].mean()

# %%
df.loc[0]['age']

# %%
df['bmi_mean'] = df['bmi'].fillna(df.groupby(df['age']//10)['bmi'].mean())

print(round(df['bmi_mean'].mean(), 3))

# %%
print(df['bmi'].unique())

# %%
#df['age_10'] = df['age']//10

#for i in df['bmi']:
   # if df.loc[i]['bmi'] is None:
      #  df.loc[i]['bmi'].fillna(df.groupby(df['df_age10'])['bmi'].mean(), inplace = True)

#print(round(df['bmi'].maen()), 3)

# %% [markdown]
# Q5. avg_glucose_level 컬럼의 값이 200이상인 데이터를 모두 199로 변경하고 stroke값이 1인 데이터의 avg_glucose_level값의 평균을 소수점이하 3자리 까지 구하여라

# %%
df.avg_glucose_level

# %%
df.loc[df.avg_glucose_level >=200, 'avg_glucose_level'] = 199
q5 = round(df[df.stroke == 1].avg_glucose_level.mean(), 3)
print(q5)

# %% [markdown]
# #데이터 불러오기

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/pok/Pokemon.csv')

# %%
df.info()

# %% [markdown]
# Q6. Attack컬럼의 값을 기준으로 내림차순정렬 했을때 상위 400위까지 포켓몬들과 401~800위까지의 포켓몬들에서 전설포켓몬(Legendary컬럼)의 숫자 차이는?

# %%
up = df.sort_values('Attack', ascending = False).reset_index(drop=True)[:400]
down = df.sort_values('Attack', ascending = False).reset_index()[400:]

q6 = up['Legendary'].sum() - down['Legendary'].sum()

print(abs(q6))

# %%
up

# %%
down

# %% [markdown]
# *reset_index(drop = True) 옵션을 통해 기존 인덱스 값을 버리고 안버리고의 차이를 알 수 있음*

# %% [markdown]
# Q7. Type 1 컬럼의 종류에 따른 Total 컬럼의 평균값을 내림차순 정렬했을때 상위 3번째 Type 1은 무엇인가?

# %%
df.groupby(df['Type 1'])['Total'].mean().sort_values(ascending = False).index[2]

# %% [markdown]
# Q8.  결측치가 존재하는 행을 모두 지운 후 처음부터 순서대로 60% 데이터를 추출하여 Defense컬럼의 1분위수를 구하여라

# %%
df_2 = df.dropna(axis=0)
df_2 = df[:int(len(df)*0.6)]
a = df_2['Defense'].quantile(0.25)
b = df_2['Defense'].describe()['25%']

print(a, b)

# %% [markdown]
# Q9. Type 1 컬럼의 속성이 Fire인 포켓몬 평균 Attack 이상인 Water속성의 포켓몬 수를 구하여라

# %%
a = df[df['Type 1'] == 'Fire']['Attack'].mean()
b = (df[df['Type 1'] == 'Water']['Attack'] >= a).sum()
print(b)

# %%
df['Attack'].unique()

# %% [markdown]
# Q10. 각 세대 중(Generation 컬럼)의 Speed와 Defense 컬럼의 차이(절댓값)이 가장 큰 세대는?

# %%
cd '/content/drive/MyDrive/BigData/Exam'

# %%
# !git config --global user.name 'dydwns9436'
# !git config --global user.email 'dydwns9436@naver.com'

# !git add Final_Test_04.ipynb

# !git commit -m '2022-06-24'

# !git push
